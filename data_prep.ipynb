# %%
import csv
from pathlib import Path
import random 
import matplotlib.pyplot as plt

# %%
folder = Path("70+_clean")
out = Path("photos.csv")

photos = [p.name for p in folder.iterdir()
          if p.is_file() and p.suffix.lower() == ".jpg"]
random.shuffle(photos)
with out.open("w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["filename", "rating"])        
    for name in photos:
        writer.writerow([name])

print(f"Wrote {len(photos)} names to {out}")
# Out:
# Wrote 252 names to photos.csv
